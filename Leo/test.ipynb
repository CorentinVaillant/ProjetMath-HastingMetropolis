# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

import numpy as np

img = mpimg.imread('../ressources/externs/carte_france.png') 
villes = np.array([
    [7.12,9.7],  #Paris
    [5.98,10.58],#Rouen
    [7.8,12.28], #Lille
    [10.26,2.02], #Marseille
    [12.18,9.54], #Strasbourg
    [9.74,7.58], #Dijon
    [9.58,5.4], #Lyon
    [6.2,2.32], #Toulouse
    [4.24,4.22], #Bordeaux
    [3.54,7.52], #Nantes
    [3.4,8.88],  #Rennes
    [6.68,8.36], #Orléans
])

xmin, xmax = 0, 1306/91
ymin, ymax = 0, 1196/91

fig, ax = plt.subplots()
ax.imshow(img, extent=[xmin, xmax, ymin, ymax])  # Adjust extent to match your data range

x = np.linspace(xmin, xmax, 100)
y = np.sin(x)
ax.plot(
    [elt[0] for elt in villes], 
    [elt[1] for elt in villes], 
color='red', linewidth=2)

ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)

plt.show()
